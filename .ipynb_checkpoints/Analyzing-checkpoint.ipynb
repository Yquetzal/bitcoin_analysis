# %%
import pandas as pd
import dask.dataframe as dd
from dask.distributed import Client, LocalCluster
# %matplotlib inline

# %%
cluster=LocalCluster(dashboard_address=9090,n_workers=8,threads_per_worker=2,memory_limit='15GB')
client=Client(cluster)

# %%
cluster.scheduler
# Out:
# <Scheduler: "tcp://127.0.0.1:36039" processes: 8 cores: 16>

# %%
cluster.workers
# Out:
# {0: <Nanny: tcp://127.0.0.1:45569, threads: 2>,
#  1: <Nanny: tcp://127.0.0.1:37541, threads: 2>,
#  2: <Nanny: tcp://127.0.0.1:44299, threads: 2>,
#  3: <Nanny: tcp://127.0.0.1:43399, threads: 2>,
#  4: <Nanny: tcp://127.0.0.1:41405, threads: 2>,
#  5: <Nanny: tcp://127.0.0.1:36781, threads: 2>,
#  6: <Nanny: tcp://127.0.0.1:42829, threads: 2>,
#  7: <Nanny: tcp://127.0.0.1:33197, threads: 2>}

# %%
client
# Out:
# <Client: 'tcp://127.0.0.1:36039' processes=8 threads=16, memory=120.00 GB>

# %%
transactions = pd.read_csv("/media/ssd2/bitcoinRemy/tr_actor2actor.tsv",sep="\t")

# %%
transactions.columns = ["timestamp","sender","receiver","value"] #Set column names

# %%
transactions['date'] = pd.to_datetime(transactions['timestamp'],unit='s')

# %%
transactions
# Out:
# Dask DataFrame Structure:
#                  timestamp  sender receiver  value
# npartitions=1135
#                      int64  object   object  int64
#                        ...     ...      ...    ...
# ...                    ...     ...      ...    ...
#                        ...     ...      ...    ...
#                        ...     ...      ...    ...
# Dask Name: rename, 2270 tasks

# %%
def add_prices(df):
    prices= pd.read_csv("/media/ssd2/bitcoinRemy/btc.csv")
    prices['day'] = pd.to_datetime(prices['date'])
    prices.set_index("day")
    return dd.merge(df,prices[["day","PriceUSD"]],on="day",how="left")
def improvev_values(df):
    df["value"]=df["value"]/100000000
    df["value_Dol"]=df["PriceUSD"]*df["value"]
def create_day_column(df):
    df["day"]=df["date"].dt.floor("d")

# %%
transactions= dd.read_parquet("/media/ssd2/bitcoinRemy/tr_actor2actor_indexed/")

# %%
transactions.head()
# Out:
#     timestamp  sender receiver         value                date        day  \
# 0  1231473279  mining       -2  5.000000e-07 2009-01-09 03:54:39 2009-01-09
# 1  1231469665  mining       -3  5.000000e-07 2009-01-09 02:54:25 2009-01-09
# 2  1231469744  mining       -4  5.000000e-07 2009-01-09 02:55:44 2009-01-09
# 3  1231470988  mining       -5  5.000000e-07 2009-01-09 03:16:28 2009-01-09
# 4  1231006505  mining       -6  5.000000e-07 2009-01-03 18:15:05 2009-01-03
#
#    value_Dol
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
transactions.to_parquet("/media/ssd2/bitcoinRemy/tr_actor2actor_day",partition_on="day")

# %%
len(days)

# %%
transactions['date'] = dd.to_datetime(transactions['timestamp'],unit='s')
create_day_column(transactions)
#add_prices(transactions)
#transactions=transactions.drop(["PriceUSD"],axis=1)
#improvev_values(transactions)

# %%
transactions = add_prices(transactions)
improvev_values(transactions)
transactions=transactions.drop(["PriceUSD"],axis=1)

# %%
len(transactions)
# Out:
# 768963716

# %%
subset=transactions.head(n=100000)

# %%
subset.to_parquet()

# %%
subset.sort_index()
# Out:
#                       timestamp  sender  receiver         value        day  \
# date
# 2009-01-03 18:15:05  1231006505  mining        -6  5.000000e-07 2009-01-03
# 2009-01-09 02:54:25  1231469665  mining        -3  5.000000e-07 2009-01-09
# 2009-01-09 02:55:44  1231469744  mining        -4  5.000000e-07 2009-01-09
# 2009-01-09 03:02:53  1231470173  mining       -16  5.000000e-07 2009-01-09
# 2009-01-09 03:16:28  1231470988  mining        -5  5.000000e-07 2009-01-09
# ...                         ...     ...       ...           ...        ...
# 2010-07-18 14:06:01  1279461961  mining  10381091  5.000000e-07 2010-07-18
# 2010-07-18 14:08:45  1279462125  mining   1812145  5.000000e-07 2010-07-18
# 2010-07-18 14:17:10  1279462630  mining    642841  5.000000e-07 2010-07-18
# 2010-07-18 14:44:08  1279464248  mining    -63458  5.002000e-07 2010-07-18
# 2010-07-18 14:49:09  1279464549  mining  33938155  5.000000e-07 2010-07-18
#
#                         value_Dol
# date
# 2009-01-03 18:15:05           NaN
# 2009-01-09 02:54:25           NaN
# 2009-01-09 02:55:44           NaN
# 2009-01-09 03:02:53           NaN
# 2009-01-09 03:16:28           NaN
# ...                           ...
# 2010-07-18 14:06:01  4.292000e-08
# 2010-07-18 14:08:45  4.292000e-08
# 2010-07-18 14:17:10  4.292000e-08
# 2010-07-18 14:44:08  4.293717e-08
# 2010-07-18 14:49:09  4.292000e-08
#
# [100000 rows x 6 columns]

# %%
subset=subset.set_index("date")

# %%
transactions.to_parquet("/media/ssd2/bitcoinRemy/tr_actor2actor_clean_step")

# %%
transactions=transactions.set_index("date",sorted=False)

# %%
transactions.npartitions
# Out:
# 3272

# %%
transactions = transactions.repartition(freq='1D')

# %%
transactions.to_csv()

# %%
transactions.to_parquet("/media/ssd2/bitcoinRemy/tr_actor2actor_indexed")

# %%
transactions.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-e18f163f63b0> in <module>
# ----> 1 transactions.head()
#
# ~/.local/lib/python3.6/site-packages/dask/dataframe/core.py in head(self, n, npartitions, compute)
#    1034             Whether to compute the result, default is True.
#    1035         """
# -> 1036         return self._head(n=n, npartitions=npartitions, compute=compute, safe=True)
#    1037
#    1038     def _head(self, n, npartitions, compute, safe):
#
# ~/.local/lib/python3.6/site-packages/dask/dataframe/core.py in _head(self, n, npartitions, compute, safe)
#    1067
#    1068         if compute:
# -> 1069             result = result.compute()
#    1070         return result
#    1071
#
# ~/.local/lib/python3.6/site-packages/dask/base.py in compute(self, **kwargs)
#     277         dask.base.compute
#     278         """
# --> 279         (result,) = compute(self, traverse=False, **kwargs)
#     280         return result
#     281
#
# ~/.local/lib/python3.6/site-packages/dask/base.py in compute(*args, **kwargs)
#     553     )
#     554
# --> 555     dsk = collections_to_dsk(collections, optimize_graph, **kwargs)
#     556     keys, postcomputes = [], []
#     557     for x in collections:
#
# ~/.local/lib/python3.6/site-packages/dask/base.py in collections_to_dsk(collections, optimize_graph, optimizations, **kwargs)
#     329         for opt, val in groups.items():
#     330             dsk, keys = _extract_graph_and_keys(val)
# --> 331             dsk = opt(dsk, keys, **kwargs)
#     332
#     333             for opt in optimizations:
#
# ~/.local/lib/python3.6/site-packages/dask/dataframe/optimize.py in optimize(dsk, keys, **kwargs)
#      36         keys,
#      37         dependencies=dependencies,
# ---> 38         fuse_subgraphs=fuse_subgraphs,
#      39     )
#      40     dsk, _ = cull(dsk, keys)
#
# ~/.local/lib/python3.6/site-packages/dask/optimization.py in fuse(dsk, keys, dependencies, ave_width, max_width, max_height, max_depth_new_edges, rename_keys, fuse_subgraphs)
#     598             child = children_stack[-1]
#     599             if child != parent:
# --> 600                 children = reducible & deps[child]
#     601                 while children:
#     602                     # Depth-first search
#
# KeyError: ('assign-d1509af275228ebfcbf67fbc3cf796a1', 1139)

# %%
transactions.known_divisions
# Out:
# False

# %%
def inputs_outputs_lists(df,name):
    df=df.copy()
    sent=df[df["sender"]==name][["value_Dol"]].groupby(df["day"]).sum()
    received=df[df["receiver"]==name][["value_Dol"]].groupby(df["day"]).sum()
    in_out=sent.join(received,how="outer",lsuffix="_sent",rsuffix="_received")
    return in_out
def amounts_owns(in_out):
    return ((in_out.cumsum()["value_received"]-in_out.cumsum()["value_sent"]))

# %%
def create_subset(name):
    return(transactions_price[(transactions_price["receiver"]==name) | (transactions_price["sender"]==name)])

# %%
def compute_balance(dataframe,name):
    sent=dataframe[dataframe["sender"]==name][["value"]].groupby(dataframe["day"]).sum()
    received=dataframe[dataframe["receiver"]==name][["value"]].groupby(dataframe["day"]).sum()
    in_out=sent.join(received,how="outer",lsuffix="_sent",rsuffix="_received")
    return ((in_out.cumsum()["value_received"]-in_out.cumsum()["value_sent"])/100000000)

# %%
def top_receivers(dataframe):
    return (dataframe.groupby(dataframe["receiver"]).sum()/100000000).sort_values("value",ascending=False)["value"]
def top_senders(dataframe):
    return (dataframe.groupby(dataframe["sender"]).sum()/100000000).sort_values("value",ascending=False)["value"]

# %%
def filter_out_self_spending(df):
    return df[df["sender"]!=df["receiver"]]
def filter_known_actors(df):
    return df[(~df["sender"].astype(str).str.isnumeric()) &  (~df["sender"].astype(str).str.isnumeric())]

# %%
def create_static_network(df):
    df=filter_out_self_spending(df)
    return df.groupby(["sender","receiver"]).agg({'value': ['sum','count'],"value_Dol": ["sum"]})
def create_dayly_network(df):
    df=filter_out_self_spending(df)
    return df.groupby(["sender","receiver","day"]).agg({'value': ['sum','count'],"value_Dol": ["sum"]})

# %%
transactions=dd.read_csv("/media/ssd2/bitcoinRemy/tr_actor2actor.tsv", blocksize=25e6,sep="\t",dtype={'-1': 'object'})

# %%
transactions.columns = ["timestamp","sender","receiver","value"] #Set column names

# %%
transactions= dd.read_parquet("/media/ssd2/bitcoinRemy/tr_actor2actor_parquet_test/")

# %%
#transactions= dd.read_parquet("/media/ssd2/bitcoinRemy/tr_actor2actor_dollars_index.parquet/")

# %%
transactions.to_parquet("/media/ssd2/bitcoinRemy/tr_actor2actor_parquet_test")

# %%
transactions=filter_out_self_spending(transactions)

# %%
create_day_column(transactions)

# %%
transactions.head()
# Out:
#     timestamp  sender receiver  value                date  value_Dol  \
# 0  1231473279  mining       -2   50.0 2009-01-09 03:54:39        NaN
# 1  1231469665  mining       -3   50.0 2009-01-09 02:54:25        NaN
# 2  1231469744  mining       -4   50.0 2009-01-09 02:55:44        NaN
# 3  1231470988  mining       -5   50.0 2009-01-09 03:16:28        NaN
# 4  1231006505  mining       -6   50.0 2009-01-03 18:15:05        NaN
#
#          day
# 0 2009-01-09
# 1 2009-01-09
# 2 2009-01-09
# 3 2009-01-09
# 4 2009-01-03

# %%
transactions=create_dayly_network(transactions)

# %%
df = transactions.compute()
# Out:
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.scheduler - ERROR - Couldn't gather keys {"('getitem-18083bae77ed567f650503a4b9226eb0', 11)": ['tcp://127.0.0.1:40151'], "('getitem-18083bae77ed567f650503a4b9226eb0', 2)": ['tcp://127.0.0.1:35841'], "('getitem-18083bae77ed567f650503a4b9226eb0', 4)": ['tcp://127.0.0.1:35841'], "('getitem-18083bae77ed567f650503a4b9226eb0', 23)": ['tcp://127.0.0.1:35841'], "('getitem-18083bae77ed567f650503a4b9226eb0', 16)": ['tcp://127.0.0.1:35841'], "('getitem-18083bae77ed567f650503a4b9226eb0', 8)": ['tcp://127.0.0.1:35841'], "('getitem-18083bae77ed567f650503a4b9226eb0', 19)": ['tcp://127.0.0.1:40151'], "('getitem-18083bae77ed567f650503a4b9226eb0', 13)": ['tcp://127.0.0.1:40151'], "('getitem-18083bae77ed567f650503a4b9226eb0', 3)": ['tcp://127.0.0.1:40151'], "('getitem-18083bae77ed567f650503a4b9226eb0', 10)": ['tcp://127.0.0.1:35841'], "('getitem-18083bae77ed567f650503a4b9226eb0', 22)": ['tcp://127.0.0.1:40151'], "('getitem-18083bae77ed567f650503a4b9226eb0', 20)": ['tcp://127.0.0.1:40151'], "('getitem-18083bae77ed567f650503a4b9226eb0', 7)": ['tcp://127.0.0.1:40151'], "('getitem-18083bae77ed567f650503a4b9226eb0', 24)": ['tcp://127.0.0.1:40151'], "('getitem-18083bae77ed567f650503a4b9226eb0', 6)": ['tcp://127.0.0.1:35841'], "('getitem-18083bae77ed567f650503a4b9226eb0', 18)": ['tcp://127.0.0.1:35841'], "('getitem-18083bae77ed567f650503a4b9226eb0', 14)": ['tcp://127.0.0.1:35841'], "('getitem-18083bae77ed567f650503a4b9226eb0', 27)": ['tcp://127.0.0.1:35841'], "('getitem-18083bae77ed567f650503a4b9226eb0', 29)": ['tcp://127.0.0.1:35841'], "('getitem-18083bae77ed567f650503a4b9226eb0', 15)": ['tcp://127.0.0.1:40151'], "('getitem-18083bae77ed567f650503a4b9226eb0', 26)": ['tcp://127.0.0.1:40151'], "('getitem-18083bae77ed567f650503a4b9226eb0', 25)": ['tcp://127.0.0.1:35841'], "('getitem-18083bae77ed567f650503a4b9226eb0', 21)": ['tcp://127.0.0.1:35841'], "('getitem-18083bae77ed567f650503a4b9226eb0', 17)": ['tcp://127.0.0.1:40151'], "('getitem-18083bae77ed567f650503a4b9226eb0', 12)": ['tcp://127.0.0.1:35841'], "('getitem-18083bae77ed567f650503a4b9226eb0', 9)": ['tcp://127.0.0.1:40151'], "('getitem-18083bae77ed567f650503a4b9226eb0', 1)": ['tcp://127.0.0.1:40151'], "('getitem-18083bae77ed567f650503a4b9226eb0', 5)": ['tcp://127.0.0.1:40151'], "('getitem-18083bae77ed567f650503a4b9226eb0', 0)": ['tcp://127.0.0.1:35841'], "('getitem-18083bae77ed567f650503a4b9226eb0', 28)": ['tcp://127.0.0.1:40151']} state: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None] workers: ['tcp://127.0.0.1:40151', 'tcp://127.0.0.1:35841']
# NoneType: None
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-0b2d75b5997e> in <module>
# ----> 1 df = transactions.compute()
#
# ~/.local/lib/python3.6/site-packages/dask/base.py in compute(self, **kwargs)
#     277         dask.base.compute
#     278         """
# --> 279         (result,) = compute(self, traverse=False, **kwargs)
#     280         return result
#     281
#
# ~/.local/lib/python3.6/site-packages/dask/base.py in compute(*args, **kwargs)
#     559         postcomputes.append(x.__dask_postcompute__())
#     560
# --> 561     results = schedule(dsk, keys, **kwargs)
#     562     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     563
#
# ~/.local/lib/python3.6/site-packages/distributed/client.py in get(self, dsk, keys, restrictions, loose_restrictions, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    2682                     should_rejoin = False
#    2683             try:
# -> 2684                 results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    2685             finally:
#    2686                 for f in futures.values():
#
# ~/.local/lib/python3.6/site-packages/distributed/client.py in gather(self, futures, errors, direct, asynchronous)
#    1997                 direct=direct,
#    1998                 local_worker=local_worker,
# -> 1999                 asynchronous=asynchronous,
#    2000             )
#    2001
#
# ~/.local/lib/python3.6/site-packages/distributed/client.py in sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     838         else:
#     839             return sync(
# --> 840                 self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     841             )
#     842
#
# ~/.local/lib/python3.6/site-packages/distributed/utils.py in sync(loop, func, callback_timeout, *args, **kwargs)
#     335     else:
#     336         while not e.is_set():
# --> 337             e.wait(10)
#     338     if error[0]:
#     339         typ, exc, tb = error[0]
#
# /usr/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# /usr/lib/python3.6/threading.py in wait(self, timeout)
#     297             else:
#     298                 if timeout > 0:
# --> 299                     gotit = waiter.acquire(True, timeout)
#     300                 else:
#     301                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
sample = tr.sample(n = 1000000)

# %%
sample
# Out:
#              timestamp      sender    receiver      value                date  \
# day
# 2017-03-22  1490218223  -169521602  -169521604  14.271990 2017-03-22 21:30:23
# 2015-08-07  1438914127   -51184961       13157   0.000010 2015-08-07 02:22:07
# 2017-08-17  1502990031    36669993         176   0.001568 2017-08-17 17:13:51
# 2014-03-24  1395657007   ePay.info   -22805864   0.000177 2014-03-24 10:30:07
# 2015-05-23  1432377050         164    34763630   0.056446 2015-05-23 10:30:50
# ...                ...         ...         ...        ...                 ...
# 2016-06-26  1466901551    36913753    Xapo.com   0.000030 2016-06-26 00:39:11
# 2017-04-10  1491815552  -175299233  -175299234   8.769603 2017-04-10 09:12:32
# 2016-04-28  1461875967   -84619130   -84619131   0.430427 2016-04-28 20:39:27
# 2016-11-30  1480483166     1601789      211047   0.014980 2016-11-30 05:19:26
# 2016-04-18  1460944911   -82444735   -82444736   0.093214 2016-04-18 02:01:51
#
#                value_Dol
# day
# 2017-03-22  14804.371680
# 2015-08-07      0.002795
# 2017-08-17      6.757262
# 2014-03-24      0.103298
# 2015-05-23     13.488538
# ...                  ...
# 2016-06-26      0.018913
# 2017-04-10  10625.688377
# 2016-04-28    194.148375
# 2016-11-30     11.118171
# 2016-04-18     40.050248
#
# [1000000 rows x 6 columns]

# %%
dayly=create_dayly_network(sample)

# %%
dayly
# Out:
#                                                value           value_Dol
#                                                  sum count           sum
# sender     receiver            day
# -100000392 1283                2016-07-13   0.000033     1      0.021659
# -100000562 -100000563          2016-07-13   0.034140     1     22.475510
# -100000877 -100000969          2016-07-13   0.000036     1      0.023700
#            34779752            2016-07-13   0.000036     1      0.023700
#            HolyTransaction.com 2016-07-13   0.000036     1      0.023700
# ...                                              ...   ...           ...
# mining     ePay.info           2017-03-16  14.632701     1  17237.625860
#                                2017-08-19  14.606438     1  60767.638631
#                                2017-09-06  14.476012     1  66698.466787
#                                2017-09-16  13.562792     1  50334.698040
#                                2017-10-31  12.946059     1  83223.931381
#
# [969360 rows x 3 columns]

# %%
len(transactions)
# Out:
# 768963716

# %%
SR2 = create_subset("SilkRoad2Market")
SR = create_subset("SilkRoadMarketplace")

# %%
#in_out.div(100000000).plot(logy=True,figsize=(20,5),style=".")
in_out.plot(logy=True,figsize=(20,5),style=".")

# %%
Paymium2[(Paymium2["date"]>="2017-02-11") & (Paymium2["date"]<="2017-02-12")].head(50)
#df[(df['date'] > '2013-01-01') & (df['date'] < '2013-02-01')]
# Out:
#             timestamp       sender      receiver        value  \
# 541902056  1486786799   -156762959   Paymium.com        39060
# 541957045  1486796208   -156787869   Paymium.com       100000
# 542032215  1486809408   -156819858   Paymium.com       951400
# 542033804  1486808935      6351888   Paymium.com     45732080
# 542053926  1486810341          164   Paymium.com      3900991
# 542056056  1486810341          164   Paymium.com      1447889
# 542071203  1486815585   -156833777   Paymium.com     29918368
# 542094952  1486818351   -156842480   Paymium.com      1300000
# 542103454  1486818579  Paymium.com    -156845931      5040000
# 542103455  1486818579  Paymium.com    -156845932      4910000
# 542103456  1486818579  Paymium.com    -156845933     44900000
# 542103457  1486818579  Paymium.com    -156845934     11000000
# 542103458  1486818579  Paymium.com    -156845935      6900000
# 542103459  1486818579  Paymium.com      10241977    230000000
# 542103460  1486818579  Paymium.com        167048      5344623
# 542103461  1486818579  Paymium.com    -156845936     34257068
# 542103462  1486818579  Paymium.com  Poloniex.com    209300000
# 542103463  1486818579  Paymium.com    -156845937      4000000
# 542103464  1486818579  Paymium.com    -156845938      5000000
# 542103465  1486818579  Paymium.com        825391    947406590
# 542103466  1486818579  Paymium.com    -156845939      3600000
# 542103467  1486818579  Paymium.com      23615267      6000000
# 542103468  1486818579  Paymium.com  Poloniex.com      7100000
# 542103469  1486818579  Paymium.com       9285178    200000000
# 542103470  1486818579  Paymium.com            21     10139820
# 542103471  1486818579  Paymium.com    -156845940      7880000
# 542103472  1486818579  Paymium.com      20560943     14499800
# 542103473  1486818579  Paymium.com  Poloniex.com     25888829
# 542103474  1486818579  Paymium.com    -156845941      3106723
# 542103475  1486818579  Paymium.com        949701     51777077
# 542103476  1486818579  Paymium.com    -156845942     31066474
# 542103477  1486818579  Paymium.com      26661905      9368480
# 542103478  1486818579  Paymium.com    -156845943       159000
# 542103479  1486818579  Paymium.com    -156845944     15600000
# 542103480  1486818579  Paymium.com       2743686      7279100
# 542103481  1486818579  Paymium.com    -156845945       837136
# 542103482  1486818579  Paymium.com   Paymium.com  17540553188
# 542199108  1486830495     34540453   Paymium.com      3000000
# 542248891  1486836979  Paymium.com            18     14730000
# 542248892  1486836979  Paymium.com    -156910859     10460000
# 542248893  1486836979  Paymium.com    -156910860      2500000
# 542248894  1486836979  Paymium.com    -156910861     10460000
# 542248895  1486836979  Paymium.com           520      2500000
# 542248896  1486836979  Paymium.com       5223459      1045000
# 542248897  1486836979  Paymium.com       6050934      7572033
# 542248898  1486836979  Paymium.com            21      2790000
# 542248899  1486836979  Paymium.com      25783728      7000000
# 542248900  1486836979  Paymium.com    -156910862    400000000
# 542248901  1486836979  Paymium.com    -156910863     25910000
# 542248902  1486836979  Paymium.com       1971992    300000000
#
#                          date   value_btc
# 541902056 2017-02-11 04:19:59    0.000391
# 541957045 2017-02-11 06:56:48    0.001000
# 542032215 2017-02-11 10:36:48    0.009514
# 542033804 2017-02-11 10:28:55    0.457321
# 542053926 2017-02-11 10:52:21    0.039010
# 542056056 2017-02-11 10:52:21    0.014479
# 542071203 2017-02-11 12:19:45    0.299184
# 542094952 2017-02-11 13:05:51    0.013000
# 542103454 2017-02-11 13:09:39    0.050400
# 542103455 2017-02-11 13:09:39    0.049100
# 542103456 2017-02-11 13:09:39    0.449000
# 542103457 2017-02-11 13:09:39    0.110000
# 542103458 2017-02-11 13:09:39    0.069000
# 542103459 2017-02-11 13:09:39    2.300000
# 542103460 2017-02-11 13:09:39    0.053446
# 542103461 2017-02-11 13:09:39    0.342571
# 542103462 2017-02-11 13:09:39    2.093000
# 542103463 2017-02-11 13:09:39    0.040000
# 542103464 2017-02-11 13:09:39    0.050000
# 542103465 2017-02-11 13:09:39    9.474066
# 542103466 2017-02-11 13:09:39    0.036000
# 542103467 2017-02-11 13:09:39    0.060000
# 542103468 2017-02-11 13:09:39    0.071000
# 542103469 2017-02-11 13:09:39    2.000000
# 542103470 2017-02-11 13:09:39    0.101398
# 542103471 2017-02-11 13:09:39    0.078800
# 542103472 2017-02-11 13:09:39    0.144998
# 542103473 2017-02-11 13:09:39    0.258888
# 542103474 2017-02-11 13:09:39    0.031067
# 542103475 2017-02-11 13:09:39    0.517771
# 542103476 2017-02-11 13:09:39    0.310665
# 542103477 2017-02-11 13:09:39    0.093685
# 542103478 2017-02-11 13:09:39    0.001590
# 542103479 2017-02-11 13:09:39    0.156000
# 542103480 2017-02-11 13:09:39    0.072791
# 542103481 2017-02-11 13:09:39    0.008371
# 542103482 2017-02-11 13:09:39  175.405532
# 542199108 2017-02-11 16:28:15    0.030000
# 542248891 2017-02-11 18:16:19    0.147300
# 542248892 2017-02-11 18:16:19    0.104600
# 542248893 2017-02-11 18:16:19    0.025000
# 542248894 2017-02-11 18:16:19    0.104600
# 542248895 2017-02-11 18:16:19    0.025000
# 542248896 2017-02-11 18:16:19    0.010450
# 542248897 2017-02-11 18:16:19    0.075720
# 542248898 2017-02-11 18:16:19    0.027900
# 542248899 2017-02-11 18:16:19    0.070000
# 542248900 2017-02-11 18:16:19    4.000000
# 542248901 2017-02-11 18:16:19    0.259100
# 542248902 2017-02-11 18:16:19    3.000000

# %%
transactions.groupby(transactions["date"].dt.floor("d")).sum()["value"].plot()

# %%
Lucky.groupby(Lucky["date"].dt.floor("d")).sum()["value"].plot()

# %%
sumUsers = transactions.groupby("sender").size()

# %%
#Print the sum of values sent by user
sumUsers.names=["sender","count"]

# %%
sumUsers.sort_values("count", ascending=[False]).head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     367         try:
# --> 368             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     369         except KeyError:
#
# KeyError: 'count'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-229d438b1790> in <module>
# ----> 1 sumUsers.sort_values("count", ascending=[False]).head()
#
# ~/.local/lib/python3.6/site-packages/pandas/core/series.py in sort_values(self, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    3242         inplace = validate_bool_kwarg(inplace, "inplace")
#    3243         # Validate the axis parameter
# -> 3244         self._get_axis_number(axis)
#    3245
#    3246         # GH 5856/5853
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     368             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     369         except KeyError:
# --> 370             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#     371
#     372     @classmethod
#
# ValueError: No axis named count for object type Series

# %%
users = pd.DataFrame(sumUsers)

# %%
users = users.sort_values(0, ascending=[False])

# %%
users.head(20)
# Out:
#                                  0
# sender
# ePay.info                 30871984
# SatoshiDice.com-original  12860377
# 1                         10268566
# FaucetBOX.com              7931086
# Xapo.com                   6722856
# 31                         4916518
# Poloniex.com               4729166
# 45                         4364562
# MoonBit.co.in              4246798
# LuckyB.it                  4141084
# Huobi.com-2                3822884
# 164                        3198909
# 797453                     3005326
# 4                          2905955
# Bittrex.com                2805075
# 5                          2661420
# Genesis-Mining.com         2462529
# mining                     2074435
# 1314926                    1987446
# DeepBit.net                1540885

# %%
transactions["tr"]=sumUsers

# %%
transactions.head()
# Out:
#     timestamp  sender receiver       value                date  tr
# 0  1231473279  mining       -2  5000000000 2009-01-09 03:54:39 NaN
# 1  1231469665  mining       -3  5000000000 2009-01-09 02:54:25 NaN
# 2  1231469744  mining       -4  5000000000 2009-01-09 02:55:44 NaN
# 3  1231470988  mining       -5  5000000000 2009-01-09 03:16:28 NaN
# 4  1231006505  mining       -6  5000000000 2009-01-03 18:15:05 NaN
