# %%
import json
import glob
import ntpath
import snap
import pandas as pd
import csv
import os.path
from os import path

# %% [markdown]
# # Obtain the blockchain
# The first step is to download the blockchain by running a Bitcoin node. See: https://bitcoin.org/en/full-node
# * Time: A few hours
# * Space: 300 GB (All spaces and time are for a classic Personal Computer as of January 2021)
# First configure the node properties by modifying your .conf file:
# https://riptutorial.com/bitcoin/example/26000/node-configuration
# Then launch the node
# * `bitcoind` or `bitcoind -daemon`

# %% [markdown]
# # Decode the blockchain into json
# Using bitcoin-etl https://github.com/blockchain-etl/bitcoin-etl, transform the blockchain data into standard json information.
# The description of fields is available there: https://github.com/blockchain-etl/bitcoin-etl-airflow/blob/master/dags/resources/stages/enrich/schemas/transactions.json
#
# command to run:
# * `bitcoinetl export_blocks_and_transactions --start-block 0 --end-block 700000 --batch-size 10000 --transactions-output final/tr --provider-uri http://login:password@localhost:8332`

# %%
#Utils
def get_files_from_dir(a_dir,prefix="",suffix=""):
    if path.isfile(a_dir):
        return [a_dir]
    files = glob.glob(a_dir + '/**/'+prefix+'*'+suffix, recursive=True)
    return sorted(files)

# %% [markdown]
# # Create a condensed format
# For most of what we want to do, we do not need all the data, so we create an intermediate format which is more compact.
#
# Scale: sample in json: 826 G. in condensed format: 113G

# %%
#my_dir="/media/ssd2/bitcoinRemy/outputAll/transactions"
#my_dir="/media/ed5/remyBitcoin/data-part2/transactions/"

# %%
def simplify_file(input_file,output_file):
    print("test",input_file,output_file)
    outputfile=open(output_file, "w+")
    data = []
    with open(input_file) as f:
        for ii,line in enumerate(f):
            if ii%10000==0:
                print(ii)
            #if ii==1000:
             #   break
            tr=json.loads(line)
            towrite=""
            towrite+=tr["hash"]+"\t"+str(tr["block_number"])+"\t"+str(tr["block_timestamp"])+"\t"+str(tr["fee"])+"\t"
            ins=[]
            for in_tr in tr["inputs"]:
                ins.append((in_tr["spent_transaction_hash"],in_tr["spent_output_index"]))
            towrite+=json.dumps(ins)+"\t"
            outs=[]
            for o in tr["outputs"]:
                outs.append((o["index"],o["addresses"],o["value"]))
            towrite+=json.dumps(outs)
            outputfile.write(towrite+'\n')
    outputfile.close()
            
def simplify_directory(input_dir,output_dir):
    files=get_files_from_dir(input_dir,prefix="transactions")
    for f in files:
        f_name=ntpath.basename(f)
        simplify_file(f,output_dir+"/"+f_name)

# %%
simplify_directory("/media/ed5/remyBitcoin/json-files/data-part2-json/transactions/","/media/ssd2/bitcoinRemy/minimal/data_part2_minimal")
# Out:
# test /media/ed5/remyBitcoin/json-files/data-part2-json/transactions/start_block=00500000/end_block=00509999/transactions_00500000_00509999.json /media/ssd2/bitcoinRemy/minimal/data_part2_minimal/transactions_00500000_00509999.json
# 0
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000
# 210000
# 220000
# 230000
# 240000
# 250000
# 260000
# 270000
# 280000
# 290000
# 300000
# 310000
# 320000
# 330000
# 340000
# 350000
# 360000
# 370000
# 380000
# 390000
# 400000
# 410000
# 420000
# 430000
# 440000
# 450000
# 460000
# 470000
# 480000
# 490000
# 500000
# 510000
# 520000
# 530000
# 540000
# 550000
# 560000
# 570000
# 580000
# 590000
# 600000
# 610000
# 620000
# 630000
# 640000
# 650000
# 660000
# 670000
# 680000
# 690000
# 700000
# 710000
# 720000
# 730000
# 740000
# 750000
# 760000
# 770000
# 780000
# 790000
# 800000
# 810000
# 820000
# 830000
# 840000
# 850000
# ...

# %% [markdown]
# # Matching inputs to previous outputs
# When bitcoin-etl exports into .json, the input information does not contain addresses and amounts. Although there is an option to export it with bitcoin-etl, the process is extremely slow, so it is more efficient to do it in one pass in python. (input information is composed of the hash and output_id of the incoming transaction, so we match each input to the described output to retrieve this information)

# %%
#match inputs v2
names=["hash","block","timestamp","fee","inputs","outputs"]
def match_inputs(input_dir,output_dir,unspent_file,current_unspent=None):
    """
    note that the function can export and import the current list of unspent transactions to allow updating without recomputing everything
    """
    input_files=get_files_from_dir(input_dir)
    
    unspent_outputs=dict()
    if current_unspent!=None:
        print("reloading previous file: "+current_unspent)
        unspent_outputs_files=pd.read_csv(current_unspent,sep="\t",index_col=False)
        for (_,hash_i,id_i,info_i) in unspent_outputs_files.itertuples():
            unspent_outputs[(hash_i,id_i)]=json.loads(info_i)

    for input_file in input_files:
        print(input_file,len(unspent_outputs))
        #first, memorize all outputs of the file, and add to previous unspent outputs
        with open(input_file) as f:
            for ii,line in enumerate(f):
                items=line.split("\t")
                outs=json.loads(items[-1])
                for out in outs:
                    unspent_outputs[(items[0],out[0])]=[out[1],out[2]]
                    
        output_file=output_dir+"/"+ntpath.basename(input_file)
        outputfile=open(output_file, "w+")
        with open(input_file) as f:
            for ii,line in enumerate(f):
                items=line[:-1].split("\t")
                inputs=json.loads(items[-2])
                inputs_matched=[]
                for input_source in inputs:
                    id_source=(input_source[0],input_source[1])
                    if id_source in unspent_outputs:
                        info=unspent_outputs[id_source]
                        id_source_to_write=(input_source[0],input_source[1],info[0],info[1])
                        inputs_matched.append(id_source_to_write)
                        #input_source+=unspent_outputs[id_source]
                        del unspent_outputs[id_source]
                    else:
                        print("input not found: ",line)
                #if len(inputs_matched)>0:
                outputfile.write(items[0]+"\t"+items[1]+"\t"+items[2]+"\t"+items[3]+"\t"+json.dumps(inputs_matched)+"\t"+items[5])
                outputfile.write('\n')
        outputfile.close()
        
    outputfile=open(unspent_file, "w+")
    outputfile.write("hash\tid\tinfo\n")
    for (h,i),v in unspent_outputs.items(): 
        outputfile.write(str(h)+"\t"+str(i)+"\t"+json.dumps(v)+"\n")
    outputfile.close()
    print(len(unspent_outputs))

# %%
match_inputs("/media/ssd2/bitcoinRemy/minimal/data_part2_minimal","/media/ssd2/bitcoinRemy/matched/data_part2_matched","/media/ed5/remyBitcoin/unspent/data-part2-unspent.tsv","/media/ed5/remyBitcoin/unspent/data-part1-unspent.tsv")
#match_inputs("/media/ssd2/bitcoinRemy/data_part1_simplified","/media/ssd2/bitcoinRemy/data_part1_matched","/media/ed5/remyBitcoin/data-part1-unspent.tsv")
# Out:
# reloading previous file: /media/ed5/remyBitcoin/unspent/data-part1-unspent.tsv
# /media/ssd2/bitcoinRemy/minimal/data_part2_minimal/transactions_00500000_00509999.json 63838917
# input not found:  fe6c48bbfdc025670f4db0340650ba5a50f9307b091d9aaa19aa44291961c69f	500000	1513622125	-34674366	[["503e4e9824282eb06f1a328484e2b367b5f4f93a405d6e7b97261bafabfb53d5", 0]]	[[0, ["3E5ZMVMzm4iZKAid54GeuebvBHvDkfukxh"], 34674366]]
#
# input not found:  1024cb12a576b69defa67dbc2f1899700ab58e5ad3d5e058edefb907f59865bc	500000	1513622125	-17450000	[["0d6cbc21a1b1a3e5df1eae4fc37aa849174b6b727e53f9f505a605f066b7f000", 0], ["aac498279d50ee81237d704cb495b243b50def5ecdcb36d9d78f596f73b1d3e9", 1]]	[[0, ["1LXnPYpHTwQeWfBVnQZ4yDP23b57NwoyrP"], 17450000]]
#
# ...
